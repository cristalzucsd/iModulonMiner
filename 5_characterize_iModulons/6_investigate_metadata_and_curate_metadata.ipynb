# %%
# imports and loading
import pandas as pd
import matplotlib.pyplot as plt

metadata_df = pd.read_csv('../Zymomonas_mobilis/Zymomonas_mobilis.txt', delimiter = '\t', index_col = 0)

# %%
pd.set_option('display.max_columns', None)
metadata_df
# Out:
#                      Run          ReleaseDate             LoadDate     spots  \
# Experiment
# SRX10341586  SRR13963594  2021-03-18 04:56:39  2021-03-15 15:29:07   9090051
# SRX10341587  SRR13963596  2021-03-18 04:56:39  2021-03-15 15:35:17   8906657
# SRX10341588  SRR13963597  2021-03-18 04:56:39  2021-03-15 15:29:57   7450610
# SRX10341589  SRR13963598  2021-03-18 04:56:39  2021-03-15 15:16:58   8222245
# SRX10341590  SRR13963599  2021-03-18 04:56:39  2021-03-15 15:19:06  12511522
# ...                  ...                  ...                  ...       ...
# SRX8694725   SRR12180121  2024-07-08 00:02:33  2020-07-09 07:37:44   4386738
# SRX8694726   SRR12180120  2024-07-08 00:02:33  2020-07-09 10:34:56   5221117
# SRX8694727   SRR12180119  2024-07-08 00:02:34  2020-07-09 07:48:26   5404286
# SRX8694728   SRR12180118  2024-07-08 00:02:34  2020-07-09 07:37:45   5242710
# SRX8694729   SRR12180117  2024-07-08 00:02:34  2020-07-09 07:42:38  12544733
#
#                   bases  spots_with_mates  avgLength  size_MB  AssemblyName  \
# Experiment
# SRX10341586  2727015300           9090051        300      881           NaN
# SRX10341587  2671997100           8906657        300      880           NaN
# SRX10341588  2235183000           7450610        300      716           NaN
# SRX10341589  2466673500           8222245        300      739           NaN
# SRX10341590  3753456600          12511522        300     1277           NaN
# ...                 ...               ...        ...      ...           ...
# SRX8694725   1316021400           4386738        300      406           NaN
# SRX8694726   1566335100           5221117        300      480           NaN
# SRX8694727   1621285800           5404286        300      498           NaN
# SRX8694728   1572813000           5242710        300      480           NaN
# SRX8694729   3763419900          12544733        300     1135           NaN
#
#                                                  download_path  \
# Experiment
# SRX10341586  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...
# SRX10341587  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...
# SRX10341588  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...
# SRX10341589  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...
# SRX10341590  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...
# ...                                                        ...
# SRX8694725   https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...
# SRX8694726   https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...
# SRX8694727   https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...
# SRX8694728   https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...
# SRX8694729   https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...
#
#                 LibraryName LibraryStrategy    LibrarySelection  \
# Experiment
# SRX10341586             NaN         RNA-Seq                cDNA
# SRX10341587             NaN         RNA-Seq                cDNA
# SRX10341588             NaN         RNA-Seq                cDNA
# SRX10341589             NaN         RNA-Seq                cDNA
# SRX10341590             NaN         RNA-Seq                cDNA
# ...                     ...             ...                 ...
# SRX8694725   pH3.8-3.5M-3-2         RNA-Seq  size fractionation
# SRX8694726   pH3.8-3.6M-3-1         RNA-Seq  size fractionation
# SRX8694727   pH3.8-3.6M-3-2         RNA-Seq  size fractionation
# SRX8694728   pH3.8-3.6M-1-1         RNA-Seq  size fractionation
# SRX8694729   pH3.8-3.6M-1-2         RNA-Seq  size fractionation
#
#               LibrarySource LibraryLayout  InsertSize  InsertDev  Platform  \
# Experiment
# SRX10341586  TRANSCRIPTOMIC        PAIRED           0          0  ILLUMINA
# SRX10341587  TRANSCRIPTOMIC        PAIRED           0          0  ILLUMINA
# SRX10341588  TRANSCRIPTOMIC        PAIRED           0          0  ILLUMINA
# SRX10341589  TRANSCRIPTOMIC        PAIRED           0          0  ILLUMINA
# SRX10341590  TRANSCRIPTOMIC        PAIRED           0          0  ILLUMINA
# ...                     ...           ...         ...        ...       ...
# SRX8694725   TRANSCRIPTOMIC        PAIRED           0          0  ILLUMINA
# SRX8694726   TRANSCRIPTOMIC        PAIRED           0          0  ILLUMINA
# SRX8694727   TRANSCRIPTOMIC        PAIRED           0          0  ILLUMINA
# SRX8694728   TRANSCRIPTOMIC        PAIRED           0          0  ILLUMINA
# SRX8694729   TRANSCRIPTOMIC        PAIRED           0          0  ILLUMINA
#
#                            Model   SRAStudy   BioProject  Study_Pubmed_id  \
# Experiment
# SRX10341586  Illumina HiSeq 2000  SRP310654  PRJNA714535              3.0
# SRX10341587  Illumina HiSeq 2000  SRP310654  PRJNA714535              3.0
# SRX10341588  Illumina HiSeq 2000  SRP310654  PRJNA714535              3.0
# SRX10341589  Illumina HiSeq 2000  SRP310654  PRJNA714535              3.0
# SRX10341590  Illumina HiSeq 2000  SRP310654  PRJNA714535              3.0
# ...                          ...        ...          ...              ...
# SRX8694725           HiSeq X Ten  SRP271015  PRJNA644990              NaN
# SRX8694726           HiSeq X Ten  SRP271015  PRJNA644990              NaN
# SRX8694727           HiSeq X Ten  SRP271015  PRJNA644990              NaN
# SRX8694728           HiSeq X Ten  SRP271015  PRJNA644990              NaN
# SRX8694729           HiSeq X Ten  SRP271015  PRJNA644990              NaN
#
#              ProjectID      Sample     BioSample SampleType   TaxID  \
# Experiment
# SRX10341586     714535  SRS8460795  SAMN18311076     simple     542
# SRX10341587     714535  SRS8460796  SAMN18311075     simple     542
# SRX10341588     714535  SRS8460797  SAMN18311074     simple     542
# SRX10341589     714535  SRS8460799  SAMN18311073     simple     542
# SRX10341590     714535  SRS8460798  SAMN18311072     simple     542
# ...                ...         ...           ...        ...     ...
# SRX8694725      644990  SRS6973250  SAMN15486759     simple  264203
# SRX8694726      644990  SRS6973251  SAMN15486760     simple  264203
# SRX8694727      644990  SRS6973252  SAMN15486761     simple  264203
# SRX8694728      644990  SRS6973253  SAMN15486762     simple  264203
# SRX8694729      644990  SRS6973254  SAMN15486763     simple  264203
#
#                                                 ScientificName  \
# Experiment
# SRX10341586                                  Zymomonas mobilis
# SRX10341587                                  Zymomonas mobilis
# SRX10341588                                  Zymomonas mobilis
# SRX10341589                                  Zymomonas mobilis
# SRX10341590                                  Zymomonas mobilis
# ...                                                        ...
# SRX8694725   Zymomonas mobilis subsp. mobilis ZM4 = ATCC 31821
# SRX8694726   Zymomonas mobilis subsp. mobilis ZM4 = ATCC 31821
# SRX8694727   Zymomonas mobilis subsp. mobilis ZM4 = ATCC 31821
# SRX8694728   Zymomonas mobilis subsp. mobilis ZM4 = ATCC 31821
# SRX8694729   Zymomonas mobilis subsp. mobilis ZM4 = ATCC 31821
#
#                  SampleName  g1k_pop_code  source  g1k_analysis_group  \
# Experiment
# SRX10341586      GSM5172101           NaN     NaN                 NaN
# SRX10341587      GSM5172102           NaN     NaN                 NaN
# SRX10341588      GSM5172103           NaN     NaN                 NaN
# SRX10341589      GSM5172104           NaN     NaN                 NaN
# SRX10341590      GSM5172105           NaN     NaN                 NaN
# ...                     ...           ...     ...                 ...
# SRX8694725   pH3.8-3.5M-3-2           NaN     NaN                 NaN
# SRX8694726   pH3.8-3.6M-3-1           NaN     NaN                 NaN
# SRX8694727   pH3.8-3.6M-3-2           NaN     NaN                 NaN
# SRX8694728   pH3.8-3.6M-1-1           NaN     NaN                 NaN
# SRX8694729   pH3.8-3.6M-1-2           NaN     NaN                 NaN
#
#              Subject_ID  Sex  Disease Tumor  Affection_Status  Analyte_Type  \
# Experiment
# SRX10341586         NaN  NaN      NaN    no               NaN           NaN
# SRX10341587         NaN  NaN      NaN    no               NaN           NaN
# SRX10341588         NaN  NaN      NaN    no               NaN           NaN
# SRX10341589         NaN  NaN      NaN    no               NaN           NaN
# SRX10341590         NaN  NaN      NaN    no               NaN           NaN
# ...                 ...  ...      ...   ...               ...           ...
# SRX8694725          NaN  NaN      NaN    no               NaN           NaN
# SRX8694726          NaN  NaN      NaN    no               NaN           NaN
# SRX8694727          NaN  NaN      NaN    no               NaN           NaN
# SRX8694728          NaN  NaN      NaN    no               NaN           NaN
# SRX8694729          NaN  NaN      NaN    no               NaN           NaN
#
#              Histological_Type  Body_Site        CenterName  Submission  \
# Experiment
# SRX10341586                NaN        NaN               GEO  SRA1206435
# SRX10341587                NaN        NaN               GEO  SRA1206435
# SRX10341588                NaN        NaN               GEO  SRA1206435
# SRX10341589                NaN        NaN               GEO  SRA1206435
# SRX10341590                NaN        NaN               GEO  SRA1206435
# ...                        ...        ...               ...         ...
# SRX8694725                 NaN        NaN  HUBEI UNIVERSITY  SRA1096659
# SRX8694726                 NaN        NaN  HUBEI UNIVERSITY  SRA1096659
# SRX8694727                 NaN        NaN  HUBEI UNIVERSITY  SRA1096659
# SRX8694728                 NaN        NaN  HUBEI UNIVERSITY  SRA1096659
# SRX8694729                 NaN        NaN  HUBEI UNIVERSITY  SRA1096659
#
#              dbgap_study_accession Consent                           RunHash  \
# Experiment
# SRX10341586                    NaN  public  B48C2658EA6148D22DD8219435192067
# SRX10341587                    NaN  public  6586637223D7A32AE80337AD397BDE2C
# SRX10341588                    NaN  public  C6722321BF94D1F5407A8BC0C01CF5AB
# SRX10341589                    NaN  public  2AFB31CCDF3F21941063F7C0F70835C7
# SRX10341590                    NaN  public  78EAE2863CD63F5D1177C6BF3B2C8366
# ...                            ...     ...                               ...
# SRX8694725                     NaN  public  969B0EB4B409AA3396081F7D79BBA2F1
# SRX8694726                     NaN  public  F4406DA01E33619540550C6579167F1F
# SRX8694727                     NaN  public  DB9B0743BBA3E3927C94BB25FD8879BA
# SRX8694728                     NaN  public  B74B8AD7C783D488949EBCC5D9167E39
# SRX8694729                     NaN  public  9DD238349449D2D69CE7139AFEE8DB12
#
#                                      ReadHash  R1  R2
# Experiment
# SRX10341586  D161D708E62066721220C16DADA3D281 NaN NaN
# SRX10341587  6D86478EA2BE04B52398319DEFE4DA78 NaN NaN
# SRX10341588  C316A8368186C05DBE955B36C0CA1DA9 NaN NaN
# SRX10341589  B7AA91D29E582AEC556770C51D8AE402 NaN NaN
# SRX10341590  5601052DCF553ED9E087C1395457DBDD NaN NaN
# ...                                       ...  ..  ..
# SRX8694725   0DF7690CE4986A29B8B868CAF021D8EF NaN NaN
# SRX8694726   87586B677C79DD6110E502334BD5BF52 NaN NaN
# SRX8694727   A2EF48CCDBB70D5C2380747EFF6D0872 NaN NaN
# SRX8694728   CD8C153282BC64DBE2ADD9603CF006DA NaN NaN
# SRX8694729   8E33F02EEC1E8892080101AA9DF9F105 NaN NaN
#
# [391 rows x 48 columns]

# %%
metadata_df.columns
# Out:
# Index(['Run', 'ReleaseDate', 'LoadDate', 'spots', 'bases', 'spots_with_mates',
#        'avgLength', 'size_MB', 'AssemblyName', 'download_path', 'LibraryName',
#        'LibraryStrategy', 'LibrarySelection', 'LibrarySource', 'LibraryLayout',
#        'InsertSize', 'InsertDev', 'Platform', 'Model', 'SRAStudy',
#        'BioProject', 'Study_Pubmed_id', 'ProjectID', 'Sample', 'BioSample',
#        'SampleType', 'TaxID', 'ScientificName', 'SampleName', 'g1k_pop_code',
#        'source', 'g1k_analysis_group', 'Subject_ID', 'Sex', 'Disease', 'Tumor',
#        'Affection_Status', 'Analyte_Type', 'Histological_Type', 'Body_Site',
#        'CenterName', 'Submission', 'dbgap_study_accession', 'Consent',
#        'RunHash', 'ReadHash', 'R1', 'R2'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)
metadata_df[metadata_df['CenterName'] == 'JGI'].dbgap_study_accession
# Out:
# Experiment
# SRX2116174   NaN
# SRX2116175   NaN
# SRX2116176   NaN
# SRX3316529   NaN
# SRX3316530   NaN
#               ..
# SRX5329190   NaN
# SRX5329191   NaN
# SRX5329192   NaN
# SRX5329193   NaN
# SRX5329194   NaN
# Name: dbgap_study_accession, Length: 96, dtype: float64

# %%
# pie charting
meta_dict = dict(metadata_df.CenterName.value_counts())
meta_names = meta_dict.keys()
meta_vals = meta_dict.values()
plt.pie(meta_vals, labels = meta_names, autopct=lambda p: f'{p:.1f}% ({int(p * sum(meta_vals) / 100)})')
plt.show()

# %%
# let's add some more columns to generate a good metadata file for later use in iModulon characterization
new_to_old = {
    'sample_id' : '',
    'study' : '',
    'project' : '',
    'condition' : '',
    'rep_id' : '',
    'Strain Description' : 'ScientificName',
    'Strain' : 'TaxID',
    'Evolved Sample' : '',
    'Base Media' : '',
    'Temperature (C)' : '',
    'pH' : '',
    'Carbon Source (g/L)' : '',
    'Nitrogen Source (g/L)' : '',
    'Electron Acceptor' : '',
    'Supplement' : '',
    'Growth Rate (1/hr)' : '',
    'Isolate Type' : 'LibrarySelection',
    'Additional Details' : '',
    'project_reference' : '',
    'Sequencing Machine' : 'Model',
    'LibraryLayout' : 'LibraryLayout',
    'Platform' : 'Platform',
    'Biological Replicates' : '',
    'doi' : '',
    'GEO' : '',
    'SRX' : 'Experiment',
    'Run' : 'Run',
    'BioProject' : 'BioProject',
    'run_date' : 'ReleaseDate',
}
iM_metadata = pd.DataFrame(columns = new_to_old.keys(), index = metadata_df.index)
for new, old in new_to_old.items():
    if old != '':
        if old == 'Experiment':
            iM_metadata[new] = metadata_df.index
        else:
            iM_metadata[new] = metadata_df[old]
            
iM_metadata.to_csv('raw_metadata_file_for_iMs.csv')
